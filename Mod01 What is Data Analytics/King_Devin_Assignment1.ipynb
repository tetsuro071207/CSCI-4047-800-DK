# %% [markdown]
# # Assignment 1
# Here we are -- Data Analytics time! WoOooooOOoOoo!
# ---
# ### Instructions
#
# Type `pip install pandas` in a teminal to ensure you have the package installed.
#
# 1. Using what we went over in class during the Jupyter tutorial, load in the data found in the **Income Data.csv** file
#     - Create a dataframe with `pandas`
# 2. Print that dataframe using a `print` statement or `df.head()`
#
# Do these steps in the code block below (you may delete the comment if you'd like).

# %%
# Code goes here
import pandas as pd

df = pd.read_csv('./Income Data.csv')
print(df)
# Out:
#                    job  type  income  education  prestige
# 0           accountant  prof      62         86        82
# 1                pilot  prof      72         76        83
# 2            architect  prof      75         92        90
# 3               author  prof      55         90        76
# 4              chemist  prof      64         86        90
# 5             minister  prof      21         84        87
# 6            professor  prof      64         93        93
# 7              dentist  prof      80        100        90
# 8             reporter    wc      67         87        52
# 9             engineer  prof      72         86        88
# 10          undertaker  prof      42         74        57
# 11              lawyer  prof      76         98        89
# 12           physician  prof      76         97        97
# 13      welfare.worker  prof      41         84        59
# 14             teacher  prof      48         91        73
# ...

# %% [markdown]
# 3. What's one thing you're proud of yourself for this week, and what's your biggest phobia?

# %% [markdown]
# I am most proud of myself this week for making it mentally to today, because I was stressing a lot monday but Im over it now.
#
# My biggest phobia is being left alone in space.

# %% [markdown]
# 4. Submit this `Jupyter` file to D2L, renamed as **Last_First_Assignment1.ipynb**
#     - Replace '**Last**' and '**First**' with your name
